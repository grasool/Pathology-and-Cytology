# %%
from path_preprocess import main

# %%
file = "./data/mcc0001-slides001.svs"

main(file)
# Out:
# Resolutions: {'level_count': 4, 'level_dimensions': ((57768, 58261), (14442, 14565), (3610, 3641), (1805, 1820)), 'level_downsamples': (1.0, 4.000034332275391, 16.001794815063477, 32.00798797607422), 'level_tile_sizes': ((240, 240), (240, 240), (240, 240), (240, 240))}
# Level 0: 112x113 (12656) 	 Resolution: 57768x58261
# Level 1: 28x28 (784) 	 Resolution: 14442x14565
# Level 2: 7x7 (49) 	 Resolution: 3610x3641
# Selected level 2 with dimensions: 3641x3610
# (8, 224, 224, 3) -> (8, 7, 7, 2048)
