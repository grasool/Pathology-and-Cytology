# %%
from path_preprocess import main

# %%
import glob

# Specify the directory
directory = '/mnt/c/Works/HnE-data-hnscc/MCC19178HnE40X'

# Get a list of all .svs files in the directory
svs_files = glob.glob(directory + '/*.svs')

# Print the file names
for file in svs_files:
    print(file)

# %%
import numpy as np
import glob

# Specify the directory
directory = 'C:\Works\HnE-data-hnscc\MCC19178HnE40X'

# Get a list of all .npy files in the directory
npy_files = glob.glob(directory + '/*.npy')

# Load each .npy file and print its shape
for file in npy_files:
    data = np.load(file)
    print(f'Shape of {file}: {data.shape}')

    print("\n the next file \n\n")
# Out:
# Shape of C:\Works\HnE-data-hnscc\MCC19178HnE40X\MCC001slide001.npy: (8, 7, 7, 2048)
#
#  the next file
#
#
# Shape of C:\Works\HnE-data-hnscc\MCC19178HnE40X\MCC002slide001.npy: (11, 7, 7, 2048)
#
#  the next file
#
#
# Shape of C:\Works\HnE-data-hnscc\MCC19178HnE40X\MCC003slide001.npy: (8, 7, 7, 2048)
#
#  the next file
#
#
# Shape of C:\Works\HnE-data-hnscc\MCC19178HnE40X\MCC007slide001.npy: (6, 7, 7, 2048)
#
#  the next file
#
#
# Shape of C:\Works\HnE-data-hnscc\MCC19178HnE40X\MCC008slide001.npy: (7, 7, 7, 2048)
#
#  the next file
#
#
# Shape of C:\Works\HnE-data-hnscc\MCC19178HnE40X\MCC008slide002.npy: (21, 7, 7, 2048)
#
#  the next file
#
#
# Shape of C:\Works\HnE-data-hnscc\MCC19178HnE40X\MCC008slide003.npy: (14, 7, 7, 2048)
#
#  the next file
#
#
# Shape of C:\Works\HnE-data-hnscc\MCC19178HnE40X\MCC009slide001.npy: (8, 7, 7, 2048)
#
#  the next file
#
#
# Shape of C:\Works\HnE-data-hnscc\MCC19178HnE40X\MCC011slide001.npy: (4, 7, 7, 2048)
#
#  the next file
#
#
# ...
