# %%
from path_preprocess import main

# %%
import glob

# Specify the directory
directory = '/mnt/c/Works/HnE-data-hnscc/MCC19178HnE40X'

# Get a list of all .svs files in the directory
svs_files = glob.glob(directory + '/*.svs')

# Print the file names
for file in svs_files:
    print(file)
    main(file)

# %%
file =  '/mnt/c/Works/HnE-data-hnscc/MCC19178HnE40X/MCC112slide001.svs'
main(file)
# Out:
# Resolutions: {'level_count': 4, 'level_dimensions': ((115536, 45271), (28884, 11317), (7221, 2829), (3610, 1414)), 'level_downsamples': (1.0, 4.0001325607299805, 16.001235961914062, 32.01034927368164), 'level_tile_sizes': ((240, 240), (240, 240), (240, 240), (240, 240))}
# Level 0: 225x88 (19800) 	 Resolution: 115536x45271
# Level 1: 56x22 (1232) 	 Resolution: 28884x11317
# Level 2: 14x5 (70) 	 Resolution: 7221x2829
# Selected level 2 with dimensions: 2829x7221
# (8, 224, 224, 3) -> (8, 7, 7, 2048)
